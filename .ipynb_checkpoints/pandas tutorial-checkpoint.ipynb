# %%
def normal(n):
    series = [0,1]
    
    if n<0:
        return "inavalid"
    elif n==0:
        return 1
    for i in range(2,n):
        series.append(series[-2]+series[-1])
    return series

print(normal(0))
# Out:
# 1

# %%
# !pip show pandas

# %%
# !python
# Out:
# Python 3.7.3 | packaged by conda-forge | (default, Mar 27 2019, 23:01:00)
# [GCC 7.3.0] :: Anaconda, Inc. on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# KeyboardInterrupt
# >>>

# %%
# !ls
# Out:
# Singleton.py		fib.py		   pattern.py
# Untitled.ipynb		frequency_list.py  postgres.sql
# abstract.py		haversine.py	   redis.txt
# atm.py			leap_year.py	   redis_conn.py
# binary_search.py	linear_search.py   return_sum_ofany_argument.py
# bubble_sort.py		link_list.py	   sample.json
# decor.py		list_compreh.py    selection_sort.py
# dict.py			locals_globals.py  smtp.py
# docker.txt		merge_sort.py	   sort.py
# exer.py			monkey.py	   special_reverse_string.py
# factorial_recursive.py	oops.py		   static_cls_inst_methd.py
# factors.py		p1		   test.py

# %%
# !pip install pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/99/f0/f99700ef327e51d291efdf4a6de29e685c4d198cbf8531541fc84d169e0e/pandas-1.3.5.tar.gz
#   Installing build dependencies ... done
# ^C
#   Getting requirements to build wheel ... canceled
# ERROR: Operation cancelled by user

# %%
# !pip3 install pandas
# Out:
# /bin/sh: 1: pip3: not found

# %%
# !pip install pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/99/f0/f99700ef327e51d291efdf4a6de29e685c4d198cbf8531541fc84d169e0e/pandas-1.3.5.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Complete output from command /snap/jupyter/6/bin/python /snap/jupyter/6/lib/python3.7/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /tmp/tmp0bqkt1yl:
#   ERROR: running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-cpython-37
#   creating build/lib.linux-x86_64-cpython-37/pandas
#   copying pandas/testing.py -> build/lib.linux-x86_64-cpython-37/pandas
#   copying pandas/_version.py -> build/lib.linux-x86_64-cpython-37/pandas
#   copying pandas/__init__.py -> build/lib.linux-x86_64-cpython-37/pandas
#   copying pandas/_typing.py -> build/lib.linux-x86_64-cpython-37/pandas
# ...

# %%
# !pip install pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/99/f0/f99700ef327e51d291efdf4a6de29e685c4d198cbf8531541fc84d169e0e/pandas-1.3.5.tar.gz
#   Installing build dependencies ... done
# ^C
#   Getting requirements to build wheel ... canceled
# ERROR: Operation cancelled by user

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
# !pip install --upgrade pip setuptools
# Out:
# ...
#      |████████████████████████████████| 2.1MB 4.9MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/c7/42/be1c7bbdd83e1bfb160c94b9cafd8e25efc7400346cf7ccdbdb452c467fa/setuptools-68.0.0-py3-none-any.whl
# ...

# %%
# !pip install pandas
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 6.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...

# %%
import pandas as pd

data = pd.read_csv('in.csv')
# df = data.rename(columns={"city":"mycity", "lat":"latitute"})
# data[["city", "lat"]]
# data.head()

# data.city.map({"Delhi":"DL", "Mumbai":"MM"})
data["short_city"] = data.city.map({"Delhi":"DL", "Mumbai":"MM"})
data
# Out:
#            city      lat      lng country short_city
# 0         Delhi  28.6600  77.2300   India         DL
# 1        Mumbai  18.9667  72.8333   India         MM
# 2       Kolkāta  22.5411  88.3378   India        NaN
# 3     Bangalore  12.9699  77.5980   India        NaN
# 4       Chennai  13.0825  80.2750   India        NaN
# ..          ...      ...      ...     ...        ...
# 401         Abu  24.5925  72.7083   India        NaN
# 402   Curchorem  15.2500  74.1000   India        NaN
# 403   Kavaratti  10.5626  72.6369   India        NaN
# 404   Panchkula  30.6915  76.8537   India        NaN
# 405  Kagaznāgār  19.3316  79.4661   India        NaN
#
# [406 rows x 5 columns]

# %%
# s = data.set_index('country')

# %%
for i in dir(pd):
    if i.startswith("read"):
        print(i)
# Out:
# read_clipboard
# read_csv
# read_excel
# read_feather
# read_fwf
# read_gbq
# read_hdf
# read_html
# read_json
# read_orc
# read_parquet
# read_pickle
# read_sas
# read_spss
# read_sql
# read_sql_query
# read_sql_table
# read_stata
# read_table
# read_xml

# %%
df = pd.read_json("http://jsonplaceholder.typicode.com/posts")

# %%
df
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...

# %%
df[(df["userId"]>5)]
# Out:
#     userId   id                                              title  \
# 50       6   51  soluta aliquam aperiam consequatur illo quis v...
# 51       6   52  qui enim et consequuntur quia animi quis volup...
# 52       6   53                           ut quo aut ducimus alias
# 53       6   54         sit asperiores ipsam eveniet odio non quia
# 54       6   55                   sit vel voluptatem et non libero
# 55       6   56                     qui et at rerum necessitatibus
# 56       6   57                                     sed ab est est
# 57       6   58            voluptatum itaque dolores nisi et quasi
# 58       6   59  qui commodi dolor at maiores et quis id accusa...
# 59       6   60  consequatur placeat omnis quisquam quia repreh...
# 60       7   61    voluptatem doloribus consectetur est ut ducimus
# 61       7   62                               beatae enim quia vel
# 62       7   63  voluptas blanditiis repellendus animi ducimus ...
# ...

# %%
df[(df["title"].str.startswith("a"))].to_csv("title_a.csv", index=False)

# %%
df.isna().sum()
# Out:
# userId    0
# id        0
# title     0
# body      0
# dtype: int64

# %%
# !ls
# Out:
# Singleton.py		frequency_list.py  postgres.sql
# Untitled.ipynb		haversine.py	   redis.txt
# abstract.py		in.csv		   redis_conn.py
# atm.py			leap_year.py	   return_sum_ofany_argument.py
# binary_search.py	linear_search.py   sample.json
# bubble_sort.py		link_list.py	   selection_sort.py
# decor.py		list_compreh.py    smtp.py
# dict.py			locals_globals.py  sort.py
# docker.txt		merge_sort.py	   special_reverse_string.py
# exer.py			monkey.py	   static_cls_inst_methd.py
# factorial_recursive.py	oops.py		   test.py
# factors.py		p1		   title_a.csv
# fib.py			pattern.py

# %%
pd.read_csv("title_a.csv")
# Out:
#    userId   id                                              title  \
# 0       2   19          adipisci placeat illum aut reiciendis qui
# 1       3   21  asperiores ea ipsam voluptatibus modi minima q...
# 2       3   24             autem hic labore sunt dolores incidunt
# 3       3   30                  a quo magni similique perferendis
# 4       5   46                 aut quo modi neque nostrum ducimus
# 5       7   67        aliquid eos sed fuga est maxime repellendus
# 6       9   90             ad iusto omnis odit dolor voluptatibus
# 7      10   91                                       aut amet sed
# 8      10  100              at nam consequatur ea labore ea harum
#
#                                                 body
# 0  illum quis cupiditate provident sit magnam\nea...
# 1  repellat aliquid praesentium dolorem quo\nsed ...
# 2  enim et ex nulla\nomnis voluptas quia qui\nvol...
# 3  alias dolor cumque\nimpedit blanditiis non eve...
# ...

# %%
df = pd.read_csv("title_a.csv")
# Out:
#    userId   id                                              title  \
# 0       2   19          adipisci placeat illum aut reiciendis qui
# 1       3   21  asperiores ea ipsam voluptatibus modi minima q...
# 2       3   24             autem hic labore sunt dolores incidunt
# 3       3   30                  a quo magni similique perferendis
# 4       5   46                 aut quo modi neque nostrum ducimus
# 5       7   67        aliquid eos sed fuga est maxime repellendus
# 6       9   90             ad iusto omnis odit dolor voluptatibus
# 7      10   91                                       aut amet sed
# 8      10  100              at nam consequatur ea labore ea harum
#
#                                                 body
# 0  illum quis cupiditate provident sit magnam\nea...
# 1  repellat aliquid praesentium dolorem quo\nsed ...
# 2  enim et ex nulla\nomnis voluptas quia qui\nvol...
# 3  alias dolor cumque\nimpedit blanditiis non eve...
# ...

# %%
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
df[df.userId>5]
# Out:
#     userId   id                                              title  \
# 50       6   51  soluta aliquam aperiam consequatur illo quis v...
# 51       6   52  qui enim et consequuntur quia animi quis volup...
# 52       6   53                           ut quo aut ducimus alias
# 53       6   54         sit asperiores ipsam eveniet odio non quia
# 54       6   55                   sit vel voluptatem et non libero
# 55       6   56                     qui et at rerum necessitatibus
# 56       6   57                                     sed ab est est
# 57       6   58            voluptatum itaque dolores nisi et quasi
# 58       6   59  qui commodi dolor at maiores et quis id accusa...
# 59       6   60  consequatur placeat omnis quisquam quia repreh...
# 60       7   61    voluptatem doloribus consectetur est ut ducimus
# 61       7   62                               beatae enim quia vel
# 62       7   63  voluptas blanditiis repellendus animi ducimus ...
# ...

# %%
gf = pd.read_csv('in.csv', names=["city_name","latitude","longitude","country_name"])

# %%
gf
# Out:
#       city_name  latitude  longitude country_name
# 0         Delhi   28.6600    77.2300        India
# 1        Mumbai   18.9667    72.8333        India
# 2       Kolkāta   22.5411    88.3378        India
# 3     Bangalore   12.9699    77.5980        India
# 4       Chennai   13.0825    80.2750        India
# ..          ...       ...        ...          ...
# 401         Abu   24.5925    72.7083        India
# 402   Curchorem   15.2500    74.1000        India
# 403   Kavaratti   10.5626    72.6369        India
# 404   Panchkula   30.6915    76.8537        India
# 405  Kagaznāgār   19.3316    79.4661        India
#
# [406 rows x 4 columns]

# %%
class JpMorgan:
    def __init__(self, name):
        self.name = name

    def full_name(self, other):
        if isinstance(other, JpMorgan):
            return self.name + " " + other.name
        else:
            raise TypeError("Can only add JpMorgan objects")

obj1 = JpMorgan("rahul")
obj2 = JpMorgan("tiwari")

result = obj1.full_name(obj2)
print(result)
# Out:
# rahul tiwari
